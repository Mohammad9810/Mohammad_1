# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
survey_raw_df=pd.read_csv("E:\Akash\survey_results_public.csv")
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
schema_raw=pd.read_csv("E:\Akash\survey_results_schema.csv",index_col="Column").QuestionText
schema_raw
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
schema_raw["YearsCode"]
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
survey_raw_df[["Country","WorkWeekHrs"]].sample(10)
# Out:
#                   Country  WorkWeekHrs
# 23173      United Kingdom         55.0
# 14416              Turkey          NaN
# 47438             Germany          NaN
# 42374               India         40.0
# 33619          Costa Rica         40.0
# 22518            Pakistan         40.0
# 18925       United States          NaN
# 33319       United States          NaN
# 33234      United Kingdom         37.0
# 36820  Russian Federation         40.0

# %%
survey_raw_df.iloc[7910]
# Out:
# Respondent                                                        7942
# MainBranch                              I am a developer by profession
# Hobbyist                                                           Yes
# Age                                                               22.0
# Age1stCode                                                          18
#                                             ...
# WebframeWorkedWith    Angular;Angular.js;Express;Flask;jQuery;React.js
# WelcomeChange                    A lot more welcome now than last year
# WorkWeekHrs                                                       45.0
# YearsCode                                                            5
# YearsCodePro                                                         1
# Name: 7910, Length: 61, dtype: object

# %%
survey_raw_df.iloc[58766]
# Out:
# Respondent                                              59928
# MainBranch                     I am a developer by profession
# Hobbyist                                                   No
# Age                                                      25.0
# Age1stCode                                                 14
#                                        ...
# WebframeWorkedWith                               Flask;jQuery
# WelcomeChange         Just as welcome now as I felt last year
# WorkWeekHrs                                              50.0
# YearsCode                                                   7
# YearsCodePro                                 Less than 1 year
# Name: 58766, Length: 61, dtype: object

# %%
survey_raw_df[["Country","WorkWeekHrs"]].sort_values(by="WorkWeekHrs",ascending=False).head(10)
# Out:
#        Country  WorkWeekHrs
# 22401   France        475.0
# 34730   Turkey        425.0
# 44913   Turkey        425.0
# 15555   Brazil        425.0
# 44745  Austria        425.0
# 44070   Turkey        425.0
# 17394  Austria        408.0
# 44257  Germany        387.0
# 59994  Denmark        385.0
# 16062   France        385.0

# %%
survey_raw_df.drop(WorkWeekHrs>85)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 survey_raw_df.drop(WorkWeekHrs>85)
#
# NameError: name 'WorkWeekHrs' is not defined

# %%
#for x in survey_raw_df.index:
    #if survey_raw_df.loc[x,"WorkWeekHrs"]>85:
        #survey_raw_df.drop(x,inplace=True)
#survey_raw_df

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df = survey_raw_df[selected_columns].copy()

# %%
survey_df.head()
# Out:
#               Country   Age Gender  \
# 0             Germany   NaN    Man
# 1      United Kingdom   NaN    NaN
# 2  Russian Federation   NaN    NaN
# 3             Albania  25.0    Man
# 4       United States  31.0    Man
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                       UndergradMajor Hobbyist Age1stCode  \
# 0  Computer science, computer engineering, or sof...      Yes         13
# 1  Computer science, computer engineering, or sof...       No         19
# 2                                                NaN      Yes         15
# 3  Computer science, computer engineering, or sof...      Yes         18
# ...

# %%
schema = schema_raw[selected_columns]

# %%
schema.head()
# Out:
# Column
# Country                                          Where do you live?
# Age               What is your age (in years)? If you prefer not...
# Gender            Which of the following describe you, if any? P...
# EdLevel           Which of the following best describes the high...
# UndergradMajor                What was your primary field of study?
# Name: QuestionText, dtype: object

# %%
schema.shape
# Out:
# (20,)

# %%
schema.ndim
# Out:
# 1

# %%
survey_df.ndim
# Out:
# 2

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
survey_df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey_df.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey_df.YearsCodePro.unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df.YearsCodePro.unique()
# Out:
# array([27.,  4., nan,  8., 13.,  2.,  7., 20.,  1., 23.,  3., 12., 17.,
#        18., 10., 14., 29.,  6., 28.,  9., 15., 11., 16., 25.,  5., 21.,
#        19., 35., 24., 32., 22., 30., 38., 26., 40., 33., 31., 34., 36.,
#        39., 37., 41., 45., 47., 42., 46., 50., 43., 44., 48., 49.])

# %%
survey_df.Age1stCode.unique()
# Out:
# array([13., 19., 15., 18., 16., 14., 12., 20., 42.,  8., 25., 22., 30.,
#        17., 21., 10., 46.,  9.,  7., 11.,  6., nan, 31., 29.,  5., 28.,
#        38., 23., 27., 41., 24., 53., 26., 35., 32., 40., 33., 36., 54.,
#        48., 56., 45., 44., 34., 39., 51., 68., 50., 37., 47., 43., 52.,
#        85., 64., 55., 58., 49., 76., 72., 73., 83., 63.])

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57473 non-null  float64
#  7   YearsCode               56784 non-null  float64
#  8   YearsCodePro            44133 non-null  float64
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df[survey_df.Age<=10]
# Out:
#               Country   Age  \
# 8793            India   3.0
# 11600        Viet Nam   5.0
# 12271         Nigeria   1.0
# 17852          Mexico  10.0
# 20042       Indonesia   1.0
# 24525  United Kingdom  10.0
# 25061     Netherlands   1.0
# 25432        Colombia  10.0
# 26952           India   7.0
# 26988          Serbia  10.0
# 30810           India  10.0
# 54687   United States   1.0
# 58292       Indonesia   1.0
# 64383       Indonesia   1.0
#
#                                                   Gender  \
# 8793                                                 Man
# 11600                                                Man
# 12271                                                Man
# 17852  Woman;Non-binary, genderqueer, or gender non-c...
# 20042                                          Woman;Man
# 24525                                                NaN
# 25061                                                NaN
# 25432                                                NaN
# ...

# %%
survey_df[survey_df.Age>=100]
# Out:
#            Country    Age Gender  \
# 14375  Netherlands  279.0    Man
#
#                                             EdLevel  \
# 14375  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 14375  Computer science, computer engineering, or sof...      Yes        16.0
#
#        YearsCode  YearsCodePro LanguageWorkedWith LanguageDesireNextYear  \
# 14375        7.0           3.0                C++                  Swift
#
#                    NEWLearn  \
# 14375  Once every few years
#
#                                                 NEWStuck          Employment  \
# 14375  Play games;Call a coworker or friend;Visit Sta...  Employed full-time
#
#                  DevType  WorkWeekHrs              JobSat  \
# 14375  Developer, mobile         40.0  Slightly satisfied
#
#                                               JobFactors NEWOvertime  \
# ...

# %%
survey_df.drop(survey_df[survey_df.Age<=10].index,inplace=True)
survey_df.drop(survey_df[survey_df.Age>=100].index,inplace=True)

# %%
survey_df.drop(survey_df[survey_df.Age<=10].index,inplace=True)
survey_df[survey_df.Age<=10]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df[survey_df.Age>=100]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 90].index, inplace=True)

# %%
survey_df[survey_df.WorkWeekHrs > 90]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            45825
# Woman                                                           3834
# Non-binary, genderqueer, or gender non-conforming                384
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           91
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
survey_df[survey_df.Gender.str.contains(';',na=False)]
# Out:
#              Country   Age                                             Gender  \
# 98     United States  42.0  Man;Non-binary, genderqueer, or gender non-con...
# 487       Kyrgyzstan  39.0  Woman;Non-binary, genderqueer, or gender non-c...
# 1101          Brazil  26.0  Man;Non-binary, genderqueer, or gender non-con...
# 1451   United States  25.0  Man;Non-binary, genderqueer, or gender non-con...
# 1662   United States  23.0  Woman;Non-binary, genderqueer, or gender non-c...
# ...              ...   ...                                                ...
# 61295  United States  19.0  Man;Non-binary, genderqueer, or gender non-con...
# 61534         Sweden  23.0  Man;Non-binary, genderqueer, or gender non-con...
# 64218         Poland  16.0  Woman;Non-binary, genderqueer, or gender non-c...
# 64234        Germany  27.0  Man;Non-binary, genderqueer, or gender non-con...
# 64252      Australia   NaN  Woman;Non-binary, genderqueer, or gender non-c...
#
# ...

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.where(~survey_df.Gender.str.contains(';',na=False))
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df[survey_df.Gender==np.nan]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df.Gender.isnull().sum()
# Out:
# 13865

# %%
survey_df[survey_df.Gender.isnull()]
# Out:
#                   Country  Age Gender  \
# 1          United Kingdom  NaN    NaN
# 2      Russian Federation  NaN    NaN
# 6                   India  NaN    NaN
# 38         United Kingdom  NaN    NaN
# 40          United States  NaN    NaN
# ...                   ...  ...    ...
# 64456       United States  NaN    NaN
# 64457             Morocco  NaN    NaN
# 64458            Viet Nam  NaN    NaN
# 64459              Poland  NaN    NaN
# 64460               Spain  NaN    NaN
#
#                                                EdLevel  \
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 6         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df=survey_df.copy()

# %%
df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# Man                                                            45825
# Woman                                                           3834
# Non-binary, genderqueer, or gender non-conforming                384
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           91
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
df.where(~(df.Gender.str.contains(';',na=False)))
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.where(~(df.Gender.str.contains(';',na=False)),np.nan,inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Gender
# Man                                                  45825
# Woman                                                 3834
# Non-binary, genderqueer, or gender non-conforming      384
# Name: count, dtype: int64

# %%
df[df.Gender.isnull()]
# Out:
#                   Country  Age Gender  \
# 1          United Kingdom  NaN    NaN
# 2      Russian Federation  NaN    NaN
# 6                   India  NaN    NaN
# 38         United Kingdom  NaN    NaN
# 40          United States  NaN    NaN
# ...                   ...  ...    ...
# 64456       United States  NaN    NaN
# 64457             Morocco  NaN    NaN
# 64458            Viet Nam  NaN    NaN
# 64459              Poland  NaN    NaN
# 64460               Spain  NaN    NaN
#
#                                                EdLevel  \
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 6         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.drop((df.Gender.str.contains(';',na=False)).index,inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.Gender
# Out:
# Series([], Name: Gender, dtype: object)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
df.drop(df[df.Gender.str.contains(';',na=False)].index,inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
survey_df.Gender.value_counts()
# Out:
# Gender
# Man                                                            45825
# Woman                                                           3834
# Non-binary, genderqueer, or gender non-conforming                384
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           91
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
survey_df.drop(survey_df[survey_df.Gender.str.contains(';',na=False)].index,inplace=True)

# %%
survey_df.Gender.value_counts()
# Out:
# Gender
# Man                                                  45825
# Woman                                                 3834
# Non-binary, genderqueer, or gender non-conforming      384
# Name: count, dtype: int64

# %%
survey_df[survey_df.Gender.isnull()]
# Out:
#                   Country  Age Gender  \
# 1          United Kingdom  NaN    NaN
# 2      Russian Federation  NaN    NaN
# 6                   India  NaN    NaN
# 38         United Kingdom  NaN    NaN
# 40          United States  NaN    NaN
# ...                   ...  ...    ...
# 64456       United States  NaN    NaN
# 64457             Morocco  NaN    NaN
# 64458            Viet Nam  NaN    NaN
# 64459              Poland  NaN    NaN
# 64460               Spain  NaN    NaN
#
#                                                EdLevel  \
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 6         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
top_countries = survey_df.Country.value_counts().head(15)
top_countries
# Out:
# Country
# United States         12365
# India                  8342
# United Kingdom         3878
# Germany                3862
# Canada                 2174
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1156
# Italy                  1114
# Russian Federation     1084
# Sweden                  878
# Pakistan                799
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title(schema.Country)
sns.barplot(x=top_countries.index, y=top_countries);

# %%
plt.figure(figsize=(12, 6))
plt.title(schema.Age)
plt.xlabel('Age')
plt.ylabel('Number of respondents')

plt.hist(survey_df.Age, bins=np.arange(10,80,5), color='purple');

# %%
survey_df[survey_df.Age<18].sort_values(by="Age",ascending=True)
# Out:
#              Country   Age Gender  \
# 55922         Turkey  11.0  Woman
# 43590  United States  11.0    Man
# 60173          India  11.0    Man
# 767    United States  11.0    NaN
# 4965   United States  11.0    Man
# ...              ...   ...    ...
# 40891          India  17.0    Man
# 19169         Israel  17.0    Man
# 40648         Poland  17.0    Man
# 19262         Norway  17.0    Man
# 64441         Canada  17.0    Man
#
#                                                  EdLevel  \
# 55922  Secondary school (e.g. American high school, G...
# 43590                                                NaN
# 60173  Secondary school (e.g. American high school, G...
# 767                            Primary/elementary school
# 4965                           Primary/elementary school
# ...                                                  ...
# 40891                          Primary/elementary school
# 19169  Secondary school (e.g. American high school, G...
# ...

# %%
survey_df.loc[(survey_df.Age>17) & (survey_df.Age<30)].sort_values(by="Age",ascending=True)
# Out:
#              Country   Age Gender  \
# 16096        Germany  18.0    Man
# 50462        Germany  18.0    Man
# 29487       Ethiopia  18.0    Man
# 1245   United States  18.0    Man
# 20196           Iran  18.0    Man
# ...              ...   ...    ...
# 12996          India  29.0    Man
# 12981         Latvia  29.0    Man
# 12948        Hungary  29.0    Man
# 48939  United States  29.0    Man
# 26577  United States  29.0    Man
#
#                                                  EdLevel  \
# 16096  Secondary school (e.g. American high school, G...
# 50462  Secondary school (e.g. American high school, G...
# 29487  Secondary school (e.g. American high school, G...
# 1245   Secondary school (e.g. American high school, G...
# 20196             I never completed any formal education
# ...                                                  ...
# 12996    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 12981  Some college/university study without earning ...
# ...

# %%
schema.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
gender_counts = survey_df.Gender.value_counts()
gender_counts
# Out:
# Gender
# Man                                                  45825
# Woman                                                 3834
# Non-binary, genderqueer, or gender non-conforming      384
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title(schema.Gender)
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=180);

# %%
schema.index
# Out:
# Index(['Country', 'Age', 'Gender', 'EdLevel', 'UndergradMajor', 'Hobbyist',
#        'Age1stCode', 'YearsCode', 'YearsCodePro', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'NEWLearn', 'NEWStuck', 'Employment',
#        'DevType', 'WorkWeekHrs', 'JobSat', 'JobFactors', 'NEWOvertime',
#        'NEWEdImpt'],
#       dtype='object', name='Column')

# %%
schema.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed?'

# %%
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
survey_df.UndergradMajor.value_counts()
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   31309
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4726
# Information systems, information technology, or system administration              4035
# A natural science (such as biology, chemistry, physics, etc.)                      2181
# Mathematics or statistics                                                          1835
# Web development or web design                                                      1766
# A business discipline (such as accounting, finance, marketing, etc.)               1366
# A humanities discipline (such as literature, history, philosophy, etc.)             996
# A social science (such as anthropology, psychology, political science, etc.)        922
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      714
# ...

# %%
survey_df.UndergradMajor.count()
# Out:
# 50543

# %%
undergrad_pct = survey_df.UndergradMajor.value_counts() * 100 / survey_df.UndergradMajor.count()
undergrad_pct
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   61.945274
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.350454
# Information systems, information technology, or system administration              7.983301
# A natural science (such as biology, chemistry, physics, etc.)                      4.315138
# Mathematics or statistics                                                          3.630572
# Web development or web design                                                      3.494055
# A business discipline (such as accounting, finance, marketing, etc.)               2.702649
# A humanities discipline (such as literature, history, philosophy, etc.)            1.970599
# A social science (such as anthropology, psychology, political science, etc.)       1.824189
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.412659
# ...

# %%
sns.barplot(x=undergrad_pct, y=undergrad_pct.index)

plt.title(schema.UndergradMajor)
plt.ylabel(None);
plt.xlabel('Percentage');

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
survey_df.Employment.value_counts()
# Out:
# Employment
# Employed full-time                                      44917
# Student                                                  7732
# Independent contractor, freelancer, or self-employed     5581
# Not employed, but looking for work                       2324
# Employed part-time                                       2195
# Not employed, and not looking for work                    318
# Retired                                                   241
# Name: count, dtype: int64

# %%
survey_df.Employment.count()
# Out:
# 63308

# %%
Emp_pct=survey_df.Employment.value_counts()*100/survey_df.Employment.count()
Emp_pct
# Out:
# Employment
# Employed full-time                                      70.949959
# Student                                                 12.213306
# Independent contractor, freelancer, or self-employed     8.815632
# Not employed, but looking for work                       3.670942
# Employed part-time                                       3.467176
# Not employed, and not looking for work                   0.502306
# Retired                                                  0.380679
# Name: count, dtype: float64

# %%
sns.barplot(x=Emp_pct,y=Emp_pct.index,color="g")
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
survey_df.DevType.to_frame().sample(15)
# Out:
#                                                  DevType
# 29674   Developer, full-stack;Engineer, site reliability
# 44153                                                NaN
# 27957  Database administrator;Developer, back-end;Dev...
# 49859          Developer, back-end;Developer, QA or test
# 64190                           Data or business analyst
# 2991                               Developer, full-stack
# 35994                              Developer, full-stack
# 26697                                Developer, back-end
# 31857  Developer, desktop or enterprise applications;...
# 63737                                                NaN
# 1773                                                 NaN
# 4350                                                 NaN
# 47214                                                NaN
# 52606  Database administrator;Developer, back-end;Sys...
# 41406                                                NaN

# %%
def split_multicolumn(col_series):
    result_df=survey_df.DevType.to_frame()
    options=[]
    for idx,value in survey_df.DevType[survey_df.DevType.notnull()].items():
        #print(idx,value)
        #print(value)
        for option in value.split(";"):
            #print(option)
            if not option in result_df.columns:
                options.append(option)
                #print(options)
                result_df[option]=False
                #print(result_df[option])
            result_df.loc[idx,option]=True
            #print(result_df.loc[idx,option])
    return result_df[options]

# %%
split_multicolumn(survey_df.DevType)
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
def split_multicolumn(col_series):
    result_df=survey_df.DevType.to_frame()
    options=[]
    for idx,value in survey_df.DevType[survey_df.DevType.notnull()].items():
        #print(idx,value)
        #print(value)
        for option in value.split(";"):
            #print(option)
            if not option in result_df.columns:
                options.append(option)
                #print(options)
                result_df[option]=False
                #print(result_df[option])
            result_df.loc[idx,option]=True
            #print(result_df.loc[idx,option])
    return result_df

# %%
split_multicolumn(survey_df.DevType)
# Out:
#                                                  DevType  \
# 0      Developer, desktop or enterprise applications;...
# 1                Developer, full-stack;Developer, mobile
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# ...

# %%
survey_df.DevType.to_frame()
# Out:
#                                                  DevType
# 0      Developer, desktop or enterprise applications;...
# 1                Developer, full-stack;Developer, mobile
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
# [63908 rows x 1 columns]

# %%
survey_df.DevType.to_frame()
options=[]
for idx,value in survey_df.DevType:
    print(idx,value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 3
#       1 survey_df.DevType.to_frame()
#       2 options=[]
# ----> 3 for idx,value in survey_df.DevType:
#       4     print(idx,value)
#
# ValueError: too many values to unpack (expected 2)

# %%
survey_df.DevType.to_frame()
options=[]
for idx,value in survey_df.DevType[survey_df.DevType.notnull()].items():
    pass
    #print(idx,value)

# %%
survey_df.DevType.to_frame()
options=[]
for idx,value in survey_df.DevType[survey_df.DevType.notnull()].items():
    #print(idx,value)
    for option in value.split(";"):
        pass
       #print(idx,option)

# %%
person={"Name":"Tom","Sex":"Male"}
for key in person.items():
        print(key)
# Out:
# ('Name', 'Tom')
# ('Sex', 'Male')

# %%
person={"Name":"Tom","Sex":"Male"}

for key,value in person.items():
        print(key,value)
# Out:
# Name Tom
# Sex Male

# %%
person={"Name":"Tom","Sex":"Male"}

for key,value in person:
        print(key,value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[334], line 3
#       1 person={"Name":"Tom","Sex":"Male"}
# ----> 3 for key,value in person:
#       4         print(key,value)
#
# ValueError: too many values to unpack (expected 2)

# %%
def split_multicolumn(col_series):
    result_df=survey_df.DevType.to_frame()
    options=[]
    for idx,value in survey_df.DevType[survey_df.DevType.notnull()].items():
        #print(idx,value)
        #print(value)
        for option in value.split(";"):
            #print(option)
            if not option in result_df.columns:
                options.append(option)
                #print(options)
                result_df[option]=False
                #print(result_df[option])
            result_df.loc[idx,option]=True
            #print(result_df.loc[idx,option])
    return result_df[options]

# %%
dev_type_df = split_multicolumn(survey_df.DevType)
dev_type_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)
dev_type_totals
# Out:
# Developer, back-end                              26919
# Developer, full-stack                            26841
# Developer, front-end                             18071
# Developer, desktop or enterprise applications    11639
# Developer, mobile                                 9355
# DevOps specialist                                 5892
# Database administrator                            5629
# Designer                                          5226
# System administrator                              5154
# Developer, embedded applications or devices       4675
# Data or business analyst                          3958
# Data scientist or machine learning specialist     3921
# Developer, QA or test                             3873
# Engineer, data                                    3684
# Academic researcher                               3483
# Educator                                          2877
# Developer, game or graphics                       2741
# ...

# %%
def split_multicolumn(col_series):
    result_df=col_series.to_frame()
    options=[]
    for idx,value in col_series[col_series.notnull()].items():
        #print(idx,value)
        #print(value)
        for option in value.split(";"):
            #print(option)
            if not option in result_df.columns:
                options.append(option)
                #print(options)
                result_df[option]=False
                #print(result_df[option])
            result_df.loc[idx,option]=True
            #print(result_df.loc[idx,option])
    return result_df[options]

# %%
survey_df.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 63908, dtype: object

# %%
languages_worked_df = split_multicolumn(survey_df.LanguageWorkedWith)
languages_worked_df
# Out:
#           C#  HTML/CSS  JavaScript  Swift  Objective-C  Python   Ruby    SQL  \
# 0       True      True        True  False        False   False  False  False
# 1      False     False        True   True        False   False  False  False
# 2      False     False       False   True         True    True  False  False
# 3      False     False       False  False        False   False  False  False
# 4      False      True       False  False        False   False   True   True
# ...      ...       ...         ...    ...          ...     ...    ...    ...
# 64456  False     False       False  False        False   False  False  False
# 64457   True      True        True   True         True    True   True   True
# 64458  False     False       False  False        False   False  False  False
# 64459  False      True       False  False        False   False  False  False
# 64460   True      True        True  False        False   False  False   True
#
# ...

# %%
languages_worked_df.count()
# Out:
# C#                       63908
# HTML/CSS                 63908
# JavaScript               63908
# Swift                    63908
# Objective-C              63908
# Python                   63908
# Ruby                     63908
# SQL                      63908
# Java                     63908
# PHP                      63908
# C                        63908
# TypeScript               63908
# Bash/Shell/PowerShell    63908
# Kotlin                   63908
# R                        63908
# VBA                      63908
# Perl                     63908
# Scala                    63908
# C++                      63908
# Go                       63908
# Haskell                  63908
# Rust                     63908
# Dart                     63908
# Julia                    63908
# Assembly                 63908
# dtype: int64

# %%
38426*100/63872
# Out:
# 60.160946893787575

# %%
languages_worked_df_totals = languages_worked_df.sum().sort_values(ascending=False)
languages_worked_df_totals
# Out:
# JavaScript               38454
# HTML/CSS                 35826
# SQL                      31102
# Python                   25049
# Java                     22865
# Bash/Shell/PowerShell    18779
# C#                       17853
# PHP                      14836
# TypeScript               14414
# C++                      13555
# C                        12345
# Go                        4984
# Kotlin                    4417
# Ruby                      4001
# Assembly                  3493
# VBA                       3460
# Swift                     3353
# R                         3252
# Rust                      2888
# Objective-C               2310
# Dart                      2252
# Scala                     2024
# Perl                      1768
# Haskell                   1195
# Julia                      502
# dtype: int64

# %%
languages_worked_percentages = (languages_worked_df_totals*100/languages_worked_df.count()).sort_values(ascending=False)
languages_worked_percentages
# Out:
# JavaScript               60.170871
# HTML/CSS                 56.058709
# SQL                      48.666834
# Python                   39.195406
# Java                     35.777993
# Bash/Shell/PowerShell    29.384428
# C#                       27.935470
# PHP                      23.214621
# TypeScript               22.554297
# C++                      21.210177
# C                        19.316830
# Go                        7.798711
# Kotlin                    6.911498
# Ruby                      6.260562
# Assembly                  5.465669
# VBA                       5.414033
# Swift                     5.246604
# R                         5.088565
# Rust                      4.518996
# Objective-C               3.614571
# Dart                      3.523815
# Scala                     3.167053
# Perl                      2.766477
# Haskell                   1.869875
# Julia                     0.785504
# dtype: float64

# %%
plt.figure(figsize=(12,9))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index)
plt.title("Languages used in the past year");
plt.xlabel('count');

# %%
languages_interested_df = split_multicolumn(survey_df.LanguageDesireNextYear)

# %%
languages_interested_df
# Out:
#           C#  HTML/CSS  JavaScript  Python  Swift  Objective-C   Java   Ruby  \
# 0       True      True        True   False  False        False  False  False
# 1      False     False       False    True   True        False  False  False
# 2      False     False       False    True   True         True  False  False
# 3      False     False       False   False  False        False  False  False
# 4      False     False       False   False  False        False   True   True
# ...      ...       ...         ...     ...    ...          ...    ...    ...
# 64456  False     False       False   False  False        False  False  False
# 64457   True      True        True    True   True         True   True   True
# 64458  False     False       False   False  False        False  False  False
# 64459  False      True        True   False  False        False   True  False
# 64460   True      True        True   False  False        False   True  False
#
# ...

# %%
languages_interested_df_totals = languages_interested_df.sum().sort_values(ascending=False)
languages_interested_df_totals
# Out:
# Python                   26423
# JavaScript               25959
# HTML/CSS                 20562
# SQL                      19776
# TypeScript               16978
# C#                       13523
# Java                     13142
# Go                       12478
# Bash/Shell/PowerShell    11597
# Rust                     10451
# C++                       9642
# Kotlin                    9472
# PHP                       7021
# C                         6007
# Swift                     5576
# Dart                      4686
# R                         4218
# Ruby                      4126
# Scala                     3420
# Haskell                   2952
# Assembly                  2415
# Julia                     1632
# Objective-C               1500
# Perl                      1131
# VBA                       1034
# dtype: int64

# %%
languages_interested_percentages = (languages_interested_df_totals*100/languages_interested_df.count()).sort_values(ascending=False)
languages_interested_percentages
# Out:
# Python                   41.345371
# JavaScript               40.619328
# HTML/CSS                 32.174376
# SQL                      30.944483
# TypeScript               26.566314
# C#                       21.160105
# Java                     20.563936
# Go                       19.524942
# Bash/Shell/PowerShell    18.146398
# Rust                     16.353195
# C++                      15.087313
# Kotlin                   14.821306
# PHP                      10.986105
# C                         9.399449
# Swift                     8.725042
# Dart                      7.332415
# R                         6.600113
# Ruby                      6.456156
# Scala                     5.351443
# Haskell                   4.619140
# Assembly                  3.778870
# Julia                     2.553671
# Objective-C               2.347124
# Perl                      1.769731
# VBA                       1.617951
# dtype: float64

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_interested_percentages, y=languages_interested_percentages.index)
plt.title("Languages people are intersted in learning over the next year");
plt.xlabel('count');

# %%
languages_loved_df=languages_worked_df & languages_interested_df
languages_loved_df
# Out:
#        Assembly  Bash/Shell/PowerShell      C     C#    C++   Dart     Go  \
# 0         False                  False  False   True  False  False  False
# 1         False                  False  False  False  False  False  False
# 2         False                  False  False  False  False  False  False
# 3         False                  False  False  False  False  False  False
# 4         False                  False  False  False  False  False  False
# ...         ...                    ...    ...    ...    ...    ...    ...
# 64456     False                  False  False  False  False  False  False
# 64457      True                   True   True   True   True   True   True
# 64458     False                  False  False  False  False  False  False
# 64459     False                  False  False  False  False  False  False
# 64460     False                  False  False   True  False  False  False
#
#        HTML/CSS  Haskell   Java  ...   Perl  Python      R   Ruby   Rust  \
# ...

# %%
languages_loved_df.sum()
# Out:
# Assembly                  1016
# Bash/Shell/PowerShell    10086
# C                         4074
# C#                       10649
# C++                       5888
# Dart                      1395
# Go                        3100
# HTML/CSS                 19164
# Haskell                    614
# Java                     10088
# JavaScript               22443
# Julia                      309
# Kotlin                    2775
# Objective-C                536
# PHP                       5521
# Perl                       503
# Python                   16686
# R                         1445
# Ruby                      1711
# Rust                      2485
# SQL                      17607
# Scala                     1079
# Swift                     1994
# TypeScript                9674
# VBA                        675
# dtype: int64

# %%
languages_worked_df.sum().sort_values(ascending=False)
# Out:
# JavaScript               38454
# HTML/CSS                 35826
# SQL                      31102
# Python                   25049
# Java                     22865
# Bash/Shell/PowerShell    18779
# C#                       17853
# PHP                      14836
# TypeScript               14414
# C++                      13555
# C                        12345
# Go                        4984
# Kotlin                    4417
# Ruby                      4001
# Assembly                  3493
# VBA                       3460
# Swift                     3353
# R                         3252
# Rust                      2888
# Objective-C               2310
# Dart                      2252
# Scala                     2024
# Perl                      1768
# Haskell                   1195
# Julia                      502
# dtype: int64

# %%
languages_interested_df.sum().sort_values(ascending=False)
# Out:
# Python                   26423
# JavaScript               25959
# HTML/CSS                 20562
# SQL                      19776
# TypeScript               16978
# C#                       13523
# Java                     13142
# Go                       12478
# Bash/Shell/PowerShell    11597
# Rust                     10451
# C++                       9642
# Kotlin                    9472
# PHP                       7021
# C                         6007
# Swift                     5576
# Dart                      4686
# R                         4218
# Ruby                      4126
# Scala                     3420
# Haskell                   2952
# Assembly                  2415
# Julia                     1632
# Objective-C               1500
# Perl                      1131
# VBA                       1034
# dtype: int64

# %%
languages_interested_df.count()
# Out:
# C#                       63908
# HTML/CSS                 63908
# JavaScript               63908
# Python                   63908
# Swift                    63908
# Objective-C              63908
# Java                     63908
# Ruby                     63908
# Scala                    63908
# PHP                      63908
# Rust                     63908
# R                        63908
# SQL                      63908
# Go                       63908
# TypeScript               63908
# Assembly                 63908
# Bash/Shell/PowerShell    63908
# C                        63908
# Haskell                  63908
# Perl                     63908
# C++                      63908
# Julia                    63908
# Kotlin                   63908
# Dart                     63908
# VBA                      63908
# dtype: int64

# %%
languages_loved_percentages = (languages_loved_df.sum() * 100/ languages_interested_df.count()).sort_values(ascending=False)
languages_loved_percentages
# Out:
# JavaScript               35.117669
# HTML/CSS                 29.986856
# SQL                      27.550541
# Python                   26.109407
# C#                       16.663016
# Java                     15.785191
# Bash/Shell/PowerShell    15.782062
# TypeScript               15.137385
# C++                       9.213244
# PHP                       8.638981
# C                         6.374789
# Go                        4.850723
# Kotlin                    4.342179
# Rust                      3.888402
# Swift                     3.120110
# Ruby                      2.677286
# R                         2.261063
# Dart                      2.182825
# Scala                     1.688365
# Assembly                  1.589785
# VBA                       1.056206
# Haskell                   0.960756
# Objective-C               0.838706
# Perl                      0.787069
# Julia                     0.483508
# dtype: float64

# %%
languages_loved_percentages = (languages_loved_df.sum() * 100/ languages_worked_df.sum()).sort_values(ascending=False)
languages_loved_percentages

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_loved_percentages, y=languages_loved_percentages.index)
plt.title("Most loved languages");
plt.xlabel('count');

# %%
countries_df = survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs', ascending=False)
countries_df.head(10)
# Out:
#                                   WorkWeekHrs
# Country
# Kuwait                              58.222222
# Grenada                             50.000000
# Iraq                                48.583333
# Maldives                            47.300000
# United Republic of Tanzania         46.000000
# Jordan                              45.806452
# Tajikistan                          45.000000
# Saint Vincent and the Grenadines    45.000000
# Niger                               45.000000
# Liechtenstein                       45.000000

# %%
(survey_df.Country.value_counts() > 250).sort_values(ascending=False).head(15)
# Out:
# Country
# United States    True
# Indonesia        True
# Iran             True
# Belgium          True
# Ireland          True
# Philippines      True
# Argentina        True
# Denmark          True
# Greece           True
# Portugal         True
# Norway           True
# Hungary          True
# China            True
# Viet Nam         True
# New Zealand      True
# Name: count, dtype: bool

# %%
high_response_countries_df = countries_df.loc[survey_df.Country.value_counts() > 250].head(15)
high_response_countries_df
# Out:
#                WorkWeekHrs
# Country
# Iran             43.612040
# Israel           43.396675
# China            41.769784
# United States    41.758182
# Greece           40.923529
# South Africa     40.855882
# Turkey           40.663677
# New Zealand      40.457551
# Belgium          40.444444
# Hungary          40.194340
# Canada           40.163248
# Japan            40.039409
# Viet Nam         40.016949
# Bangladesh       39.842553
# Australia        39.828234

# %%
schema.YearsCodePro
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %%
plt.title(schema.Age1stCode)
sns.histplot(x=survey_df.Age1stCode, bins=30, kde=True);

# %%
language_dislike_df=~languages_interested_df
language_dislike_df
# Out:
#           C#  HTML/CSS  JavaScript  Python  Swift  Objective-C   Java   Ruby  \
# 0      False     False       False    True   True         True   True   True
# 1       True      True        True   False  False         True   True   True
# 2       True      True        True   False  False        False   True   True
# 3       True      True        True    True   True         True   True   True
# 4       True      True        True    True   True         True  False  False
# ...      ...       ...         ...     ...    ...          ...    ...    ...
# 64456   True      True        True    True   True         True   True   True
# 64457  False     False       False   False  False        False  False  False
# 64458   True      True        True    True   True         True   True   True
# 64459   True     False       False    True   True         True  False   True
# 64460  False     False       False    True   True         True  False   True
#
# ...

# %%
language_dislike_df.sum().sort_values(ascending=False)
# Out:
# VBA                      62874
# Perl                     62777
# Objective-C              62408
# Julia                    62276
# Assembly                 61493
# Haskell                  60956
# Scala                    60488
# Ruby                     59782
# R                        59690
# Dart                     59222
# Swift                    58332
# C                        57901
# PHP                      56887
# Kotlin                   54436
# C++                      54266
# Rust                     53457
# Bash/Shell/PowerShell    52311
# Go                       51430
# Java                     50766
# C#                       50385
# TypeScript               46930
# SQL                      44132
# HTML/CSS                 43346
# JavaScript               37949
# Python                   37485
# dtype: int64
